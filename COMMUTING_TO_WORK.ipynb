# %% [markdown]
# # Commuting to Work Script
# Run all of these code blocks in order to create the COMMUTING_TO_WORK data table.

# %% [markdown]
# ### Import Statements

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Function to create row for each year

# %%
def commuting(file,year):
    # Read in file
    df = pd.read_csv(file)

    # Get rid of spaces in Labels
    df['Label'] = df['Label'].apply(lambda x: x.lstrip())

    # Convert percentage estimates to float
    df['Percentage'] = df['Estimate'].apply(lambda x: float(x.rstrip('%'))/100 if '%' in x else None)

    # Keep only full population stats (excluded mean travel time to work)
    df = df.iloc[:8]

    # Move Total Workers 16+ from row to column
    df['Total Workers 16+'] = int(df.iloc[0]['Estimate'].replace(',',''))
    df.dropna(inplace=True)

    # Drop unnecessary columns
    df.drop(columns=['Estimate','Margin of Error'], inplace=True)

    # Calculate population estimates
    df['Population Estimate'] = df['Percentage']*df['Total Workers 16+']

    # Drop unnecessary columns
    df.drop(columns=['Percentage','Total Workers 16+'], inplace=True)

    # Change index and transpose table
    df.set_index('Label', inplace=True)
    df = df.T

    # Change index to year
    df.index = [year]

    # Calculate extra columns
    df['Total Workers 16+'] = df.sum(axis=1)

    # Rename all columns with abbreviated underscored naming conventions
    df.rename(columns={'Car, truck, or van - drove alone':'drove_alone', 'Car, truck, or van - carpooled':'carpooled', 'Public transportation (excluding taxicab)':'pub_trans', 'Walked':'walked', 'Other means':'other', 'Total Workers 16+':'total_workers_16_plus', 'Worked at home':'wah', 'Worked from home':'wfh1'}, inplace=True)

    return df

# %% [markdown]
# ### Test that function works

# %%
commuting('data/2014/COMMUTING_TO_WORK.CSV',2014)
# Out:
# Label  drove_alone  carpooled  pub_trans    walked    other      wah  \
# 2014     28027.818   5614.336   6184.542  2017.652  921.102  1096.55
#
# Label  total_workers_16_plus
# 2014                 43862.0

# %% [markdown]
# ### Test that function works for each year
# Should return only "No file for year '2020'"

# %%
for year in range(2010,2023):
    file = 'data/'+str(year)+'/COMMUTING_TO_WORK.CSV'

    try:
        commuting(file,year)
    except:
        print(f"No file for year '{year}'")
# Out:
# No file for year '2020'

# %% [markdown]
# ### Run function for each year

# %%
COMMUTING_TO_WORK_2022 = commuting('data/2022/COMMUTING_TO_WORK.CSV',2022)
COMMUTING_TO_WORK_2021 = commuting('data/2021/COMMUTING_TO_WORK.CSV',2021)
COMMUTING_TO_WORK_2019 = commuting('data/2019/COMMUTING_TO_WORK.CSV',2019)
COMMUTING_TO_WORK_2018 = commuting('data/2018/COMMUTING_TO_WORK.CSV',2018)
COMMUTING_TO_WORK_2017 = commuting('data/2017/COMMUTING_TO_WORK.CSV',2017)
COMMUTING_TO_WORK_2016 = commuting('data/2016/COMMUTING_TO_WORK.CSV',2016)
COMMUTING_TO_WORK_2015 = commuting('data/2015/COMMUTING_TO_WORK.CSV',2015)
COMMUTING_TO_WORK_2014 = commuting('data/2014/COMMUTING_TO_WORK.CSV',2014)
COMMUTING_TO_WORK_2013 = commuting('data/2013/COMMUTING_TO_WORK.CSV',2013)
COMMUTING_TO_WORK_2012 = commuting('data/2012/COMMUTING_TO_WORK.CSV',2012)
COMMUTING_TO_WORK_2011 = commuting('data/2011/COMMUTING_TO_WORK.CSV',2011)
COMMUTING_TO_WORK_2010 = commuting('data/2010/COMMUTING_TO_WORK.CSV',2010)

# %% [markdown]
# ### Combine each year into single dataframe containing all years

# %%
COMMUTING_TO_WORK = pd.concat([COMMUTING_TO_WORK_2022,COMMUTING_TO_WORK_2021,COMMUTING_TO_WORK_2019,COMMUTING_TO_WORK_2018,COMMUTING_TO_WORK_2017,COMMUTING_TO_WORK_2016,COMMUTING_TO_WORK_2015,COMMUTING_TO_WORK_2014,COMMUTING_TO_WORK_2013,COMMUTING_TO_WORK_2012,COMMUTING_TO_WORK_2011,COMMUTING_TO_WORK_2010])
COMMUTING_TO_WORK
# Out:
# Label  drove_alone  carpooled  pub_trans    walked     other      wfh1  \
# 2022     27745.377   6429.410   4599.501  1582.624  1681.538  7418.550
# 2021     26519.519   5503.156   3273.429  2182.286  1138.584  8824.026
# 2019     29234.948   7271.384   8815.308  1743.140   647.452  2141.572
# 2018     31948.320   4363.200   7417.440  2278.560  1163.520       NaN
# 2017     28833.696   5258.976   7480.440  1677.432  1133.400       NaN
# 2016     26647.740   4610.482   6344.700  1015.152  1861.112       NaN
# 2015     29000.702   5466.586   6717.415  2640.639   880.213       NaN
# 2014     28027.818   5614.336   6184.542  2017.652   921.102       NaN
# 2013     26292.952   4717.008   8473.144  2664.236   960.872       NaN
# 2012     27037.912   7362.234   5553.966  2109.646   129.162       NaN
# 2011     28507.512   4078.635   6826.347  1889.052   515.196       NaN
# 2010     26122.644   4291.872   7428.240  1403.112   660.288       NaN
#
# Label  total_workers_16_plus       wah
# 2022               49457.000       NaN
# 2021               47441.000       NaN
# 2019               49853.804       NaN
# 2018               48480.000  1308.960
# 2017               45336.000   952.056
# 2016               42298.000  1818.814
# 2015               46327.000  1621.445
# 2014               43862.000  1096.550
# 2013               43676.000   567.788
# 2012               43010.946   818.026
# 2011               42975.933  1159.191
# 2010               41268.000  1361.844

# %% [markdown]
# ### Combine work from/at home into single columns

# %%
COMMUTING_TO_WORK['wfh'] = COMMUTING_TO_WORK['wfh1'].combine_first(COMMUTING_TO_WORK['wah'])
COMMUTING_TO_WORK = COMMUTING_TO_WORK.drop(columns=['wfh1', 'wah'])
COMMUTING_TO_WORK
# Out:
# Label  drove_alone  carpooled  pub_trans    walked     other  \
# 2022     27745.377   6429.410   4599.501  1582.624  1681.538
# 2021     26519.519   5503.156   3273.429  2182.286  1138.584
# 2019     29234.948   7271.384   8815.308  1743.140   647.452
# 2018     31948.320   4363.200   7417.440  2278.560  1163.520
# 2017     28833.696   5258.976   7480.440  1677.432  1133.400
# 2016     26647.740   4610.482   6344.700  1015.152  1861.112
# 2015     29000.702   5466.586   6717.415  2640.639   880.213
# 2014     28027.818   5614.336   6184.542  2017.652   921.102
# 2013     26292.952   4717.008   8473.144  2664.236   960.872
# 2012     27037.912   7362.234   5553.966  2109.646   129.162
# 2011     28507.512   4078.635   6826.347  1889.052   515.196
# 2010     26122.644   4291.872   7428.240  1403.112   660.288
#
# Label  total_workers_16_plus       wfh
# 2022               49457.000  7418.550
# 2021               47441.000  8824.026
# 2019               49853.804  2141.572
# 2018               48480.000  1308.960
# 2017               45336.000   952.056
# 2016               42298.000  1818.814
# 2015               46327.000  1621.445
# 2014               43862.000  1096.550
# 2013               43676.000   567.788
# 2012               43010.946   818.026
# 2011               42975.933  1159.191
# 2010               41268.000  1361.844

# %% [markdown]
# ### Rearrange columns

# %%
COMMUTING_TO_WORK = COMMUTING_TO_WORK[['drove_alone','carpooled','pub_trans','walked','other','wfh','total_workers_16_plus']]
COMMUTING_TO_WORK
# Out:
# Label  drove_alone  carpooled  pub_trans    walked     other       wfh  \
# 2022     27745.377   6429.410   4599.501  1582.624  1681.538  7418.550
# 2021     26519.519   5503.156   3273.429  2182.286  1138.584  8824.026
# 2019     29234.948   7271.384   8815.308  1743.140   647.452  2141.572
# 2018     31948.320   4363.200   7417.440  2278.560  1163.520  1308.960
# 2017     28833.696   5258.976   7480.440  1677.432  1133.400   952.056
# 2016     26647.740   4610.482   6344.700  1015.152  1861.112  1818.814
# 2015     29000.702   5466.586   6717.415  2640.639   880.213  1621.445
# 2014     28027.818   5614.336   6184.542  2017.652   921.102  1096.550
# 2013     26292.952   4717.008   8473.144  2664.236   960.872   567.788
# 2012     27037.912   7362.234   5553.966  2109.646   129.162   818.026
# 2011     28507.512   4078.635   6826.347  1889.052   515.196  1159.191
# 2010     26122.644   4291.872   7428.240  1403.112   660.288  1361.844
#
# Label  total_workers_16_plus
# 2022               49457.000
# 2021               47441.000
# 2019               49853.804
# 2018               48480.000
# 2017               45336.000
# 2016               42298.000
# 2015               46327.000
# 2014               43862.000
# 2013               43676.000
# 2012               43010.946
# 2011               42975.933
# 2010               41268.000

# %% [markdown]
# ### Reset index on combined dataframe

# %%
COMMUTING_TO_WORK.reset_index(inplace=True)
COMMUTING_TO_WORK.rename(columns={'index':'year'}, inplace=True)
COMMUTING_TO_WORK
# Out:
# Label  year  drove_alone  carpooled  pub_trans    walked     other       wfh  \
# 0      2022    27745.377   6429.410   4599.501  1582.624  1681.538  7418.550
# 1      2021    26519.519   5503.156   3273.429  2182.286  1138.584  8824.026
# 2      2019    29234.948   7271.384   8815.308  1743.140   647.452  2141.572
# 3      2018    31948.320   4363.200   7417.440  2278.560  1163.520  1308.960
# 4      2017    28833.696   5258.976   7480.440  1677.432  1133.400   952.056
# 5      2016    26647.740   4610.482   6344.700  1015.152  1861.112  1818.814
# 6      2015    29000.702   5466.586   6717.415  2640.639   880.213  1621.445
# 7      2014    28027.818   5614.336   6184.542  2017.652   921.102  1096.550
# 8      2013    26292.952   4717.008   8473.144  2664.236   960.872   567.788
# 9      2012    27037.912   7362.234   5553.966  2109.646   129.162   818.026
# 10     2011    28507.512   4078.635   6826.347  1889.052   515.196  1159.191
# 11     2010    26122.644   4291.872   7428.240  1403.112   660.288  1361.844
#
# Label  total_workers_16_plus
# 0                  49457.000
# 1                  47441.000
# 2                  49853.804
# 3                  48480.000
# 4                  45336.000
# 5                  42298.000
# 6                  46327.000
# 7                  43862.000
# 8                  43676.000
# 9                  43010.946
# 10                 42975.933
# 11                 41268.000

# %% [markdown]
# ### Save final dataframe as CSV to 'final' folder in 'data' folder

# %%
COMMUTING_TO_WORK.to_csv('data/final/COMMUTING_TO_WORK.CSV', index=False)

# %% [markdown]
# ### Check that dataframe was saved properly as CSV

# %%
df = pd.read_csv('data/final/COMMUTING_TO_WORK.CSV')
df
# Out:
#     year  drove_alone  carpooled  pub_trans    walked     other       wfh  \
# 0   2022    27745.377   6429.410   4599.501  1582.624  1681.538  7418.550
# 1   2021    26519.519   5503.156   3273.429  2182.286  1138.584  8824.026
# 2   2019    29234.948   7271.384   8815.308  1743.140   647.452  2141.572
# 3   2018    31948.320   4363.200   7417.440  2278.560  1163.520  1308.960
# 4   2017    28833.696   5258.976   7480.440  1677.432  1133.400   952.056
# 5   2016    26647.740   4610.482   6344.700  1015.152  1861.112  1818.814
# 6   2015    29000.702   5466.586   6717.415  2640.639   880.213  1621.445
# 7   2014    28027.818   5614.336   6184.542  2017.652   921.102  1096.550
# 8   2013    26292.952   4717.008   8473.144  2664.236   960.872   567.788
# 9   2012    27037.912   7362.234   5553.966  2109.646   129.162   818.026
# 10  2011    28507.512   4078.635   6826.347  1889.052   515.196  1159.191
# 11  2010    26122.644   4291.872   7428.240  1403.112   660.288  1361.844
#
#     total_workers_16_plus
# 0               49457.000
# 1               47441.000
# 2               49853.804
# 3               48480.000
# 4               45336.000
# 5               42298.000
# 6               46327.000
# 7               43862.000
# 8               43676.000
# 9               43010.946
# 10              42975.933
# 11              41268.000
